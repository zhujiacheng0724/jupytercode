# %%
import matplotlib.pyplot as plt
import cv2
import skimage
import numpy as np

# %%
import skimage.io as io

# %%
img1 =io.imread("zjcdy.JPG")

# %%
plt.imshow(img)

# %%
img =skimage.data.chelsea()
plt.imshow(img)
print(skimage.data_dir)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\data

# %%
io.imsave("testcat.jpg",img)

# %%
print(img.shape)
# Out:
# (300, 451, 3)

# %%
print(img1.shape)
# Out:
# (6894, 4480, 3)
